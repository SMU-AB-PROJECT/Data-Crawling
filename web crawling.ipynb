# %%
pip install google_images_download
# Out:
# Collecting google_images_download
#   Downloading google_images_download-2.8.0.tar.gz (14 kB)
# Collecting selenium
#   Downloading selenium-3.141.0-py2.py3-none-any.whl (904 kB)
# Requirement already satisfied: urllib3 in c:\users\admin\anaconda3\lib\site-packages (from selenium->google_images_download) (1.25.9)
# Building wheels for collected packages: google-images-download
#   Building wheel for google-images-download (setup.py): started
#   Building wheel for google-images-download (setup.py): finished with status 'done'
#   Created wheel for google-images-download: filename=google_images_download-2.8.0-py2.py3-none-any.whl size=14555 sha256=b6d938fd04ed623d0e66606e5beb8e5da9be8f98c9ffeb4509dc83ecbca75619
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\09\09\00\7a4b1a816f726438cb51067db23c7f9efedf009b6a1bfa027a
# Successfully built google-images-download
# Installing collected packages: selenium, google-images-download
# Successfully installed google-images-download-2.8.0 selenium-3.141.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pygame
# Out:
# Collecting pygame
#   Downloading pygame-2.0.1-cp38-cp38-win_amd64.whl (5.2 MB)
# Installing collected packages: pygame
# Successfully installed pygame-2.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import re
import time
import socket

from urllib.request import urlretrieve
from urllib.error import HTTPError, URLError
from selenium import webdriver
from selenium.common.exceptions import ElementClickInterceptedException, NoSuchElementException, ElementNotInteractableException
from PIL import Image
from pygame import mixer
from datetime import date
# Out:
# pygame 2.0.1 (SDL 2.0.14, Python 3.8.3)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
class Crawler:
    def __init__(self):
        # 이미지들이 저장될 경로 및 폴더 이름
        self.path = "D:/현주폴더/상명/3-2/크롤링/스파게티"
        self.date = str(date.today())

        # 검색어 입력 및 중복 검사
        self.query = input("입력: ")
        while self.checking(self.query) is True:
            self.query = input("입력: ")

        # 드라이버 경로 지정 (Chrome)
        self.driver = webdriver.Edge("D:\msedgedriver.exe")

        # clickAndRetrieve() 과정에서 urlretrieve이 너무 오래 걸릴 경우를 대비해 타임 아웃 지정
        socket.setdefaulttimeout(30)

        # 크롤링한 이미지 수
        self.crawled_count = 0

        # mp3 파일 경로
        self.mp3 = "./Mococo_Seed.mp3"

    def scroll_down(self):
        scroll_count = 0

        print("> 스크롤 다운 시작")

        # 스크롤 위치값 얻고 last_height 에 저장
        last_height = self.driver.execute_script("return document.body.scrollHeight")

        # 결과 더보기 버튼을 클릭했는지 유무
        after_click = False

        while True:
            print(f"> 스크롤 횟수: {scroll_count}")
            # 스크롤 다운
            self.driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            scroll_count += 1
            time.sleep(2)

            # 스크롤 위치값 얻고 new_height 에 저장
            new_height = self.driver.execute_script("return document.body.scrollHeight")

            # 스크롤이 최하단이며
            if last_height == new_height:

                # 결과 더보기 버튼을 클릭한적이 있는 경우
                if after_click is True:
                    print("> 스크롤 다운 종료")
                    break

                # 결과 더보기 버튼을 클릭한적이 없는 경우
                if after_click is False:
                    if self.driver.find_element_by_css_selector(".mye4qd").is_displayed():
                        self.driver.find_element_by_css_selector(".mye4qd").click()
                        print("> 결과 더보기 클릭")
                        after_click = True
                    elif NoSuchElementException:
                        print("> 이미지 갯수가 100개 이하임")
                        print("> 스크롤 다운 종료")
                        break

            last_height = new_height

    def click_and_retrieve(self, index, img, img_list_length):

        try:
            # 이미지 클릭
            img.click()
            time.sleep(1.5)
            src = self.driver.find_element_by_xpath('//*[@id="Sva75c"]/div/div/div[3]/div[2]/c-wiz/div/div[1]/div[1]/div/div[2]/a/img').get_attribute('src')

            # 저장될 이미지 파일 경로
            dst = f"{self.path}/{self.date}/{self.query}/{self.crawled_count + 1}"

            # 확장자
            if re.search(r"jpeg|png", src):
                ext = re.search(r"jpeg|png", src).group()
            else:
                ext = "jpg"

            # 이미지 저장
            urlretrieve(src, f"{dst}.{ext}")
            print(f"> {index + 1} / {img_list_length} 번째 사진 저장 ({ext})")
            self.crawled_count += 1
            if sel.crawled_count==200:
                break

        except HTTPError:
            print("> HTTPError & 패스")
            pass

    def crawling(self):

        print("> 크롤링 시작")

        # 이미지 고급검색 중 이미지 유형 '사진'
        url = f"https://www.google.com/search?as_st=y&tbm=isch&hl=ko&as_q={self.query}&as_epq=&as_oq=&as_eq=&cr=&as_sitesearch=&safe=images&tbs=itp:photo"
        self.driver.get(url)
        self.driver.maximize_window()
        self.scroll_down()

        div = self.driver.find_element_by_xpath('//*[@id="islrg"]/div[1]')
        # class_name에 공백이 있는 경우 여러 클래스가 있는 것이므로 아래와 같이 css_selector로 찾음
        img_list = div.find_elements_by_css_selector(".rg_i.Q4LuWd")

        # 다운로드 디렉토리 생성
        os.makedirs(self.path + '/' + self.date + '/' + self.query)
        print(f"> {self.path}/{self.date}/{self.query} 생성")

        for index, img in enumerate(img_list):
            try:
                self.click_and_retrieve(index, img, len(img_list))

            except ElementClickInterceptedException:
                print("> ElementClickInterceptedException")
                self.driver.execute_script("window.scrollTo(0, window.scrollY + 100)")
                print("> 100만큼 스크롤 다운 및 3초 슬립")
                time.sleep(3)
                self.click_and_retrieve(index, img, len(img_list))

            except NoSuchElementException:
                print("> NoSuchElementException")
                self.driver.execute_script("window.scrollTo(0, window.scrollY + 100)")
                print("> 100만큼 스크롤 다운 및 3초 슬립")
                time.sleep(3)
                self.click_and_retrieve(index, img, len(img_list))

            except ConnectionResetError:
                print("> ConnectionResetError & 패스")
                pass

            except URLError:
                print("> URLError & 패스")
                pass

            except socket.timeout:
                print("> socket.timeout & 패스")
                pass

            except socket.gaierror:
                print("> socket.gaierror & 패스")
                pass

            #except ElementNotInteractableException:
             #   print("> ElementNotInteractableException")
              #  break

        try:
            print("> 크롤링 종료 (성공률: %.2f%%)" % (self.crawled_count / len(img_list) * 100.0))

        except ZeroDivisionError:
            print("> img_list 가 비어있음")

        self.driver.quit()

    def filtering(self, size):
        print("> 필터링 시작")

        filtered_count = 0
        dir_name = f"{self.path}/{self.date}/{self.query}"
        for index, file_name in enumerate(os.listdir(dir_name)):
            try:
                file_path = os.path.join(dir_name, file_name)
                img = Image.open(file_path)

                # 이미지 해상도의 가로와 세로가 모두 size 이하인 경우
                if img.width <= size and img.height <= size:
                    img.close()
                    os.remove(file_path)
                    print(f"> {index} 번째 사진 삭제")
                    filtered_count += 1

            # 이미지 파일이 깨져있는 경우
            except OSError:
                os.remove(file_path)
                filtered_count += 1

        print(f"> 필터링 종료 (총 갯수: {self.crawled_count - filtered_count})")

    def checking(self, query):
        # 입력 받은 검색어가 이름인 폴더가 존재하면 중복으로 판단
        for dir_name in os.listdir(self.path):
            file_list = os.listdir(f"{self.path}/{dir_name}")
            if query in file_list:
                print(f"> 중복된 검색어: ({dir_name})")
                return True

    def playing_mp3(self):
        mixer.init()
        mixer.music.load(self.mp3)
        mixer.music.play()
        while mixer.music.get_busy():
            pass
        print(f"> 검색어: {self.query}")

# %%
crawler = Crawler()
crawler.crawling()
#crawler.filtering(350)
crawler.playing_mp3()
# Out:
# 입력: 스파게티
# > 크롤링 시작
# > 스크롤 다운 시작
# > 스크롤 횟수: 0
# > 스크롤 횟수: 1
# > 스크롤 횟수: 2
# > 스크롤 횟수: 3
# > 스크롤 횟수: 4
# > 스크롤 횟수: 5
# > 결과 더보기 클릭
# > 스크롤 횟수: 6
# > 스크롤 횟수: 7
# > 스크롤 횟수: 8
# > 스크롤 횟수: 9
# > 스크롤 횟수: 10
# > 스크롤 다운 종료
# > D:/현주폴더/상명/3-2/크롤링/김밥/2021-05-07/스파게티 생성
# > 1 / 720 번째 사진 저장 (jpg)
# > 2 / 720 번째 사진 저장 (jpg)
# > 3 / 720 번째 사진 저장 (jpg)
# > 4 / 720 번째 사진 저장 (jpg)
# > 5 / 720 번째 사진 저장 (jpg)
# > 6 / 720 번째 사진 저장 (jpg)
# > 7 / 720 번째 사진 저장 (jpg)
# > 8 / 720 번째 사진 저장 (jpg)
# > 9 / 720 번째 사진 저장 (jpg)
# > 10 / 720 번째 사진 저장 (jpg)
# > 11 / 720 번째 사진 저장 (jpeg)
# > 12 / 720 번째 사진 저장 (jpg)
# > 13 / 720 번째 사진 저장 (jpg)
# > 14 / 720 번째 사진 저장 (jpg)
# > 15 / 720 번째 사진 저장 (jpg)
# > 16 / 720 번째 사진 저장 (png)
# > 17 / 720 번째 사진 저장 (jpg)
# > 18 / 720 번째 사진 저장 (jpg)
# > 19 / 720 번째 사진 저장 (jpg)
# > 20 / 720 번째 사진 저장 (jpg)
# > 21 / 720 번째 사진 저장 (jpg)
# > 22 / 720 번째 사진 저장 (jpg)
# > 23 / 720 번째 사진 저장 (jpg)
# > 24 / 720 번째 사진 저장 (jpg)
# > 25 / 720 번째 사진 저장 (png)
# > 26 / 720 번째 사진 저장 (jpg)
# > 27 / 720 번째 사진 저장 (jpg)
# > 28 / 720 번째 사진 저장 (jpg)
# > 29 / 720 번째 사진 저장 (jpg)
# > 30 / 720 번째 사진 저장 (jpg)
# > 31 / 720 번째 사진 저장 (jpg)
# > 32 / 720 번째 사진 저장 (jpg)
# > 33 / 720 번째 사진 저장 (jpg)
# > 34 / 720 번째 사진 저장 (jpg)
# > 35 / 720 번째 사진 저장 (jpg)
# > 36 / 720 번째 사진 저장 (jpg)
# > 37 / 720 번째 사진 저장 (jpg)
# > 38 / 720 번째 사진 저장 (jpg)
# > 39 / 720 번째 사진 저장 (jpg)
# > 40 / 720 번째 사진 저장 (png)
# > 41 / 720 번째 사진 저장 (jpg)
# > 42 / 720 번째 사진 저장 (jpg)
# > 43 / 720 번째 사진 저장 (jpg)
# > 44 / 720 번째 사진 저장 (jpg)
# > 45 / 720 번째 사진 저장 (jpg)
# > 46 / 720 번째 사진 저장 (jpg)
# > 47 / 720 번째 사진 저장 (jpg)
# > 48 / 720 번째 사진 저장 (jpg)
# > 49 / 720 번째 사진 저장 (jpg)
# > 50 / 720 번째 사진 저장 (jpg)
# > 51 / 720 번째 사진 저장 (jpg)
# > 52 / 720 번째 사진 저장 (jpg)
# > 53 / 720 번째 사진 저장 (png)
# > 54 / 720 번째 사진 저장 (jpg)
# > 55 / 720 번째 사진 저장 (jpg)
# > 56 / 720 번째 사진 저장 (jpg)
# > 57 / 720 번째 사진 저장 (jpg)
# > 58 / 720 번째 사진 저장 (jpg)
# > 59 / 720 번째 사진 저장 (jpg)
# > 60 / 720 번째 사진 저장 (jpg)
# > 61 / 720 번째 사진 저장 (jpg)
# > 62 / 720 번째 사진 저장 (jpg)
# > 63 / 720 번째 사진 저장 (jpg)
# > 64 / 720 번째 사진 저장 (jpeg)
# > 65 / 720 번째 사진 저장 (jpg)
# > 66 / 720 번째 사진 저장 (jpg)
# > 67 / 720 번째 사진 저장 (jpg)
# > 68 / 720 번째 사진 저장 (jpg)
# > 69 / 720 번째 사진 저장 (jpg)
# > 70 / 720 번째 사진 저장 (jpg)
# > 71 / 720 번째 사진 저장 (jpg)
# > 72 / 720 번째 사진 저장 (jpg)
# > HTTPError & 패스
# > 74 / 720 번째 사진 저장 (jpg)
# > 75 / 720 번째 사진 저장 (jpg)
# > 76 / 720 번째 사진 저장 (jpg)
# > 77 / 720 번째 사진 저장 (jpg)
# > 78 / 720 번째 사진 저장 (jpg)
# > 79 / 720 번째 사진 저장 (jpg)
# > 80 / 720 번째 사진 저장 (jpg)
# > 81 / 720 번째 사진 저장 (jpg)
# > 82 / 720 번째 사진 저장 (jpg)
# > 83 / 720 번째 사진 저장 (jpg)
# > 84 / 720 번째 사진 저장 (jpg)
# > 85 / 720 번째 사진 저장 (jpg)
# > 86 / 720 번째 사진 저장 (jpg)
# > 87 / 720 번째 사진 저장 (jpg)
# > 88 / 720 번째 사진 저장 (jpg)
# > 89 / 720 번째 사진 저장 (jpg)
# > 90 / 720 번째 사진 저장 (jpg)
# > 91 / 720 번째 사진 저장 (jpg)
# > 92 / 720 번째 사진 저장 (jpg)
# > 93 / 720 번째 사진 저장 (jpg)
# > 94 / 720 번째 사진 저장 (jpg)
# > 95 / 720 번째 사진 저장 (jpeg)
# > 96 / 720 번째 사진 저장 (jpg)
# > 97 / 720 번째 사진 저장 (jpg)
# > 98 / 720 번째 사진 저장 (png)
# > 99 / 720 번째 사진 저장 (jpg)
# > 100 / 720 번째 사진 저장 (jpg)
# > 101 / 720 번째 사진 저장 (jpg)
# > 102 / 720 번째 사진 저장 (jpg)
# > 103 / 720 번째 사진 저장 (jpg)
# > 104 / 720 번째 사진 저장 (jpg)
# > 105 / 720 번째 사진 저장 (jpg)
# > 106 / 720 번째 사진 저장 (jpg)
# > 107 / 720 번째 사진 저장 (jpg)
# > 108 / 720 번째 사진 저장 (jpg)
# > 109 / 720 번째 사진 저장 (jpg)
# > 110 / 720 번째 사진 저장 (jpg)
# > 111 / 720 번째 사진 저장 (jpg)
# > 112 / 720 번째 사진 저장 (jpg)
# > 113 / 720 번째 사진 저장 (jpg)
# > 114 / 720 번째 사진 저장 (jpg)
# > 115 / 720 번째 사진 저장 (jpg)
# > 116 / 720 번째 사진 저장 (jpg)
# > 117 / 720 번째 사진 저장 (jpg)
# > 118 / 720 번째 사진 저장 (jpg)
# > 119 / 720 번째 사진 저장 (jpg)
# > 120 / 720 번째 사진 저장 (jpg)
# > 121 / 720 번째 사진 저장 (jpg)
# > 122 / 720 번째 사진 저장 (jpg)
# > 123 / 720 번째 사진 저장 (jpg)
# > 124 / 720 번째 사진 저장 (jpg)
# > 125 / 720 번째 사진 저장 (jpg)
# > 126 / 720 번째 사진 저장 (jpg)
# > 127 / 720 번째 사진 저장 (jpg)
# > 128 / 720 번째 사진 저장 (jpg)
# > 129 / 720 번째 사진 저장 (jpg)
# > 130 / 720 번째 사진 저장 (jpg)
# > 131 / 720 번째 사진 저장 (jpg)
# > 132 / 720 번째 사진 저장 (jpg)
# > 133 / 720 번째 사진 저장 (jpg)
# > 134 / 720 번째 사진 저장 (jpg)
# > 135 / 720 번째 사진 저장 (png)
# > HTTPError & 패스
# > 137 / 720 번째 사진 저장 (jpg)
# > 138 / 720 번째 사진 저장 (jpg)
# > 139 / 720 번째 사진 저장 (jpg)
# > 140 / 720 번째 사진 저장 (jpg)
# > 141 / 720 번째 사진 저장 (jpg)
# > 142 / 720 번째 사진 저장 (jpg)
# > 143 / 720 번째 사진 저장 (jpg)
# > 144 / 720 번째 사진 저장 (jpg)
# > 145 / 720 번째 사진 저장 (jpg)
# > 146 / 720 번째 사진 저장 (jpg)
# > 147 / 720 번째 사진 저장 (jpg)
# > 148 / 720 번째 사진 저장 (jpg)
# > 149 / 720 번째 사진 저장 (jpg)
# > 150 / 720 번째 사진 저장 (jpg)
# > HTTPError & 패스
# > 152 / 720 번째 사진 저장 (png)
# > 153 / 720 번째 사진 저장 (jpg)
# > 154 / 720 번째 사진 저장 (jpg)
# > 155 / 720 번째 사진 저장 (jpg)
# > 156 / 720 번째 사진 저장 (jpg)
# > 157 / 720 번째 사진 저장 (jpg)
# > 158 / 720 번째 사진 저장 (jpg)
# > 159 / 720 번째 사진 저장 (jpg)
# > 160 / 720 번째 사진 저장 (jpg)
# > 161 / 720 번째 사진 저장 (jpg)
# > 162 / 720 번째 사진 저장 (jpg)
# > 163 / 720 번째 사진 저장 (jpg)
# > 164 / 720 번째 사진 저장 (jpg)
# > 165 / 720 번째 사진 저장 (jpg)
# > 166 / 720 번째 사진 저장 (jpg)
# > 167 / 720 번째 사진 저장 (jpg)
# > 168 / 720 번째 사진 저장 (jpg)
# > 169 / 720 번째 사진 저장 (jpg)
# > 170 / 720 번째 사진 저장 (jpg)
# > 171 / 720 번째 사진 저장 (jpg)
# > 172 / 720 번째 사진 저장 (jpg)
# > 173 / 720 번째 사진 저장 (jpg)
# > 174 / 720 번째 사진 저장 (jpg)
# > 175 / 720 번째 사진 저장 (jpg)
# > 176 / 720 번째 사진 저장 (jpg)
# > 177 / 720 번째 사진 저장 (jpg)
# > 178 / 720 번째 사진 저장 (jpg)
# > 179 / 720 번째 사진 저장 (jpg)
# > 180 / 720 번째 사진 저장 (jpg)
# > HTTPError & 패스
# > 182 / 720 번째 사진 저장 (jpg)
# > 183 / 720 번째 사진 저장 (jpg)
# > 184 / 720 번째 사진 저장 (jpg)
# > 185 / 720 번째 사진 저장 (jpg)
# > 186 / 720 번째 사진 저장 (jpg)
# > 187 / 720 번째 사진 저장 (jpg)
# > 188 / 720 번째 사진 저장 (jpg)
# > 189 / 720 번째 사진 저장 (jpg)
# > 190 / 720 번째 사진 저장 (jpg)
# > 191 / 720 번째 사진 저장 (jpg)
# > 192 / 720 번째 사진 저장 (jpg)
# > 193 / 720 번째 사진 저장 (jpg)
# > HTTPError & 패스
# > 195 / 720 번째 사진 저장 (jpg)
# > 196 / 720 번째 사진 저장 (jpg)
# > 197 / 720 번째 사진 저장 (jpg)
# > 198 / 720 번째 사진 저장 (jpg)
# > 199 / 720 번째 사진 저장 (jpg)
# > 200 / 720 번째 사진 저장 (jpg)
# > 201 / 720 번째 사진 저장 (jpg)
# > 202 / 720 번째 사진 저장 (jpg)
# > 203 / 720 번째 사진 저장 (jpg)
# > 204 / 720 번째 사진 저장 (jpg)
# > 205 / 720 번째 사진 저장 (jpg)
# > 206 / 720 번째 사진 저장 (jpg)
# > 207 / 720 번째 사진 저장 (jpg)
# > 208 / 720 번째 사진 저장 (jpg)
# > 209 / 720 번째 사진 저장 (jpg)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-dd2041ca5beb> in <module>
#       1 crawler = Crawler()
# ----> 2 crawler.crawling()
#       3 #crawler.filtering(350)
#       4 crawler.playing_mp3()
#
# <ipython-input-29-b78a53411a49> in crawling(self)
#     110         for index, img in enumerate(img_list):
#     111             try:
# --> 112                 self.click_and_retrieve(index, img, len(img_list))
#     113
#     114             except ElementClickInterceptedException:
#
# <ipython-input-29-b78a53411a49> in click_and_retrieve(self, index, img, img_list_length)
#      69             # 이미지 클릭
#      70             img.click()
# ---> 71             time.sleep(1.5)
#      72             src = self.driver.find_element_by_xpath('//*[@id="Sva75c"]/div/div/div[3]/div[2]/c-wiz/div/div[1]/div[1]/div/div[2]/a/img').get_attribute('src')
#      73
#
# KeyboardInterrupt:
